# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# BCP = by city/province
studentBCP = pd.read_csv("school_diff_data\\시도별 학생수.csv", encoding="cp949")
studentBCP = studentBCP.rename(columns={'년도':'year', '계':'total','서울':'seoul','부산':'busan','대구':'daegu','인천':'incheon','광주':'gwangju','대전':'daejeon','울산':'ulsan','세종':'sejong','경기':'gyeonggi','강원':'gangwon','충북':'chungbuk','충남':'chungnam','전북':'jeonbuk','전남':'jeonnam','경북':'gyeongbuk','경남':'gyeongnam','제주':'jeju'})
studentBCP = studentBCP.drop(['total'], axis=1)
studentBCP
# Out:
#     year   seoul  busan  daegu  incheon  gwangju  daejeon  ulsan  sejong  \
# 0   2011  233738  85906  70489    83164    49427    45192  38010       0
# 1   2012  229293  79841  63517    78054    49742    41324  37460       0
# 2   2013  225493  75614  62136    74064    50868    40038  37005    2227
# 3   2014  215311  72175  59025    70605    49768    38848  34748    2485
# 4   2015  204931  68119  56869    67867    49446    37402  32796    3657
# 5   2016  198374  65353  54753    66037    48373    36968  31535    4924
# 6   2017  183526  61104  51583    62937    45728    34238  29529    6025
# 7   2018  165341  55440  47038    57704    42365    30905  27018    6896
# 8   2019  148956  50304  42377    53294    38396    27866  24246    7744
# 9   2020  141699  48053  39319    51908    35163    26703  22669    8400
# 10  2021  149174  48426  42183    51784    33933    26416  23452    8920
# 11  2022  146767  47995  41926    53607    32721    25506  23010    9524
# ...

# %%
# studentBCP.set_index('year', inplace=True)
fig = studentBCP.plot()
# studentBCP.reset_index('year', inplace=True)

# %%
schoolBCP =
# Out:
#     year   seoul  busan  daegu  incheon  gwangju  daejeon  ulsan  sejong  \
# 0   2011  233738  85906  70489    83164    49427    45192  38010       0
# 1   2012  229293  79841  63517    78054    49742    41324  37460       0
# 2   2013  225493  75614  62136    74064    50868    40038  37005    2227
# 3   2014  215311  72175  59025    70605    49768    38848  34748    2485
# 4   2015  204931  68119  56869    67867    49446    37402  32796    3657
# 5   2016  198374  65353  54753    66037    48373    36968  31535    4924
# 6   2017  183526  61104  51583    62937    45728    34238  29529    6025
# 7   2018  165341  55440  47038    57704    42365    30905  27018    6896
# 8   2019  148956  50304  42377    53294    38396    27866  24246    7744
# 9   2020  141699  48053  39319    51908    35163    26703  22669    8400
# 10  2021  149174  48426  42183    51784    33933    26416  23452    8920
# 11  2022  146767  47995  41926    53607    32721    25506  23010    9524
# ...
