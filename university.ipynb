# %%
import csv
import pandas as pd
import numpy as np
import googlemaps
import geocoder
import folium
import folium
from folium.plugins import HeatMap

# %%
df = pd.read_csv("대학교_개황(20220310).csv")

# %%
df.head()
# AIzaSyAZjVSvLHAlLc6MdPxJS0KdZabgblojv0A
# Out:
#   학교구분  학교코드      학교명    본분교  지역 설립구분 학교상태                    주소          경도  \
# 0   대학     1  강릉원주대학교     본교  강원   국립   기존        강원도 강릉시 죽헌길 7   128.870200
# 1   대학     2  강릉원주대학교  제2캠퍼스  강원   국립   기존  강원도 원주시 흥업면 남원로 150   127.922151
# 2   대학     3    강원대학교     본교  강원   국립   기존      강원도 춘천시 강원대학길 1   127.748390
# 3   대학     4    강원대학교  제2캠퍼스  강원   국립   기존      강원도 삼척시 중앙로 346   129.159929
# 4   대학     5    경북대학교     본교  대구   국립   기존      대구광역시 북구 대학로 80   128.614510
#
#           위도
# 0  37.765659
# 1  37.305164
# 2  37.868030
# 3  37.450720
# 4  35.889013

# %%
df_sample = df[['학교구분', '학교명', '주소', '위도', '경도']]
df_sample.head()
# Out:
#   학교구분      학교명                    주소         위도          경도
# 0   대학  강릉원주대학교        강원도 강릉시 죽헌길 7   37.765659  128.870200
# 1   대학  강릉원주대학교  강원도 원주시 흥업면 남원로 150   37.305164  127.922151
# 2   대학    강원대학교      강원도 춘천시 강원대학길 1   37.868030  127.748390
# 3   대학    강원대학교      강원도 삼척시 중앙로 346   37.450720  129.159929
# 4   대학    경북대학교      대구광역시 북구 대학로 80   35.889013  128.614510

# %%
df_sample.isnull().sum()
# Out:
# 학교구분    0
# 학교명     0
# 주소      0
# 위도      0
# 경도      0
# dtype: int64

# %%
df
# Out:
#      학교구분  학교코드                  학교명    본분교  지역   설립구분 학교상태  \
# 0      대학     1              강릉원주대학교     본교  강원     국립   기존
# 1      대학     2              강릉원주대학교  제2캠퍼스  강원     국립   기존
# 2      대학     3                강원대학교     본교  강원     국립   기존
# 3      대학     4                강원대학교  제2캠퍼스  강원     국립   기존
# 4      대학     5                경북대학교     본교  대구     국립   기존
# ..    ...   ...                  ...    ...  ..    ...  ...
# 410  전문대학  3019          한국농수산대학(일반)     본교  전북  특별법국립   기존
# 411    대학  3022            한국전통문화대학교     본교  충남  특별법국립   기존
# 412    대학  3139           한국에너지공과대학교     본교  전남  특별법법인   신설
# 413  전문대학  3157   한국폴리텍 VII 대학 진주캠퍼스     본교  경남     사립   신설
# 414  전문대학  3163  한국폴리텍 VII 대학 동부산캠퍼스     본교  부산     사립   신설
#
#                            주소          경도         위도
# 0              강원도 강릉시 죽헌길 7   128.870200  37.765659
# 1        강원도 원주시 흥업면 남원로 150   127.922151  37.305164
# 2            강원도 춘천시 강원대학길 1   127.748390  37.868030
# ...

# %%
m = folium.Map(location = [37.5665005, 126.9783021], zoom_start = 11)
HeatMap(data = df_sample[['위도', '경도']], radius = 25, max_zoom = 100).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save('a.html')
